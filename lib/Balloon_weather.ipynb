# %% [markdown]
# # 1.Importing and descriptive statistics

# %%
import pandas as pd
citypath ="C:\\Users\\wesle\\Desktop\\contest\\data\\CityData.csv"
Insitupath="C:\\Users\\wesle\\Desktop\\contest\\data\\In_situMeasurementforTraining_201712.csv"
Trainpath="C:\\Users\\wesle\\Desktop\\contest\\data\\ForecastDataforTraining_201712.csv"

# %%
city=pd.read_csv(citypath)
# city location 0 represent london is the starting point for all balloons
city
# Out:
#     cid  xid  yid
# 0     0  142  328
# 1     1   84  203
# 2     2  199  371
# 3     3  140  234
# 4     4  236  241
# 5     5  315  281
# 6     6  358  207
# 7     7  363  237
# 8     8  423  266
# 9     9  125  375
# 10   10  189  274

# %%
Insitu=pd.read_csv(Insitupath)
Insitu.head() # Real-time wind value
# Out:
#    xid  yid  date_id  hour  wind
# 0    1    1        1     3  12.8
# 1    1    2        1     3  12.8
# 2    1    3        1     3  12.6
# 3    1    4        1     3  12.1
# 4    1    5        1     3  11.6

# %% [markdown]
# Insitu data represents the data generated and collected from the real world.
# Xid and Yid forms a 548 * 421 cell blocks.
# Hour range from 3 to 20 , which means each day the balloon has 18 hours to fly across the map
# Day_id shows that we have totally 5 days, each day has one mission for navigating 10 balloons from city id 0 to the other 10 cities.

# %%
Insitu.describe()
# Out:
#                 xid           yid       date_id          hour          wind
# count  2.076372e+07  2.076372e+07  2.076372e+07  2.076372e+07  2.076372e+07
# mean   2.745000e+02  2.110000e+02  3.000000e+00  1.150000e+01  1.129610e+01
# std    1.581937e+02  1.215319e+02  1.414214e+00  5.188128e+00  5.491615e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  3.000000e+00  0.000000e+00
# 25%    1.377500e+02  1.060000e+02  2.000000e+00  7.000000e+00  7.360000e+00
# 50%    2.745000e+02  2.110000e+02  3.000000e+00  1.150000e+01  1.060000e+01
# 75%    4.112500e+02  3.160000e+02  4.000000e+00  1.600000e+01  1.490000e+01
# max    5.480000e+02  4.210000e+02  5.000000e+00  2.000000e+01  4.830000e+01

# %%
Train=pd.read_csv(Trainpath)
Train.head()
# Out:
#    xid  yid  date_id  hour  model  wind
# 0    1    1        1     3      1  13.8
# 1    1    1        1     3      2  12.8
# 2    1    1        1     3      3  10.4
# 3    1    1        1     3      4  11.1
# 4    1    1        1     3      5  13.2

# %% [markdown]
# Every day we have 10 models to forcast the weather and most of the models are 96-97 percent correct. We would like to predict the weather using the 10 models.

# %%
Train.describe()
# Out:
#                 xid           yid       date_id          hour         model  \
# count  2.076372e+08  2.076372e+08  2.076372e+08  2.076372e+08  2.076372e+08
# mean   2.745000e+02  2.110000e+02  3.000000e+00  1.150000e+01  5.500000e+00
# std    1.581937e+02  1.215319e+02  1.414214e+00  5.188127e+00  2.872281e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  3.000000e+00  1.000000e+00
# 25%    1.377500e+02  1.060000e+02  2.000000e+00  7.000000e+00  3.000000e+00
# 50%    2.745000e+02  2.110000e+02  3.000000e+00  1.150000e+01  5.500000e+00
# 75%    4.112500e+02  3.160000e+02  4.000000e+00  1.600000e+01  8.000000e+00
# max    5.480000e+02  4.210000e+02  5.000000e+00  2.000000e+01  1.000000e+01
#
#                wind
# count  2.076372e+08
# mean   1.153906e+01
# std    5.512402e+00
# min    0.000000e+00
# 25%    7.630000e+00
# 50%    1.080000e+01
# 75%    1.500000e+01
# max    4.930000e+01

# %% [markdown]
# # 2.Model Selection
# We would like to use logistic regression model for the training data. As we are only interested in whether the wind will be over 15, binary classification will be the toolkits.
# However Logistic models requires the explanatory variable X to be uncorrelately. The ten models output are highly correlated thus orthogonal decomposition is needed for data shrinkage. In this project, we would like to use Principal Component Analysis.

# %% [markdown]
# ## 2.1 reshape the data to fit the model

# %%
newtrain=Train.pivot_table(values="wind",index=["xid","yid","date_id","hour"],columns="model")
newtrain.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in mean(self, *args, **kwargs)
#    1036         try:
# -> 1037             return self._cython_agg_general('mean', **kwargs)
#    1038         except GroupByError:
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in _cython_agg_general(self, how, alt, numeric_only)
#    3280         new_items, new_blocks = self._cython_agg_blocks(
# -> 3281             how, alt=alt, numeric_only=numeric_only)
#    3282         return self._wrap_agged_blocks(new_items, new_blocks)
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in _cython_agg_blocks(self, how, alt, numeric_only)
#    3323                 result, _ = self.grouper.aggregate(
# -> 3324                     block.values, how, axis=agg_axis)
#    3325             except NotImplementedError:
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in aggregate(self, values, how, axis)
#    2062     def aggregate(self, values, how, axis=0):
# -> 2063         return self._cython_operation('aggregate', values, how, axis)
#    2064
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in _cython_operation(self, kind, values, how, axis)
#    1974                                           "supported for the 'how' argument")
# -> 1975             out_shape = (self.ngroups,) + values.shape[1:]
#    1976
#
# pandas\_libs\src\properties.pyx in pandas._libs.lib.cache_readonly.__get__ (pandas\_libs\lib.c:44442)()
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in ngroups(self)
#    1817     def ngroups(self):
# -> 1818         return len(self.result_index)
#    1819
#
# pandas\_libs\src\properties.pyx in pandas._libs.lib.cache_readonly.__get__ (pandas\_libs\lib.c:44442)()
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in result_index(self)
#    1831
# -> 1832         return MultiIndex(levels=[ping.group_index for ping in self.groupings],
#    1833                           labels=self.recons_labels,
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in <listcomp>(.0)
#    1831
# -> 1832         return MultiIndex(levels=[ping.group_index for ping in self.groupings],
#    1833                           labels=self.recons_labels,
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in group_index(self)
#    2465         if self._group_index is None:
# -> 2466             self._make_labels()
#    2467         return self._group_index
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in _make_labels(self)
#    2471             labels, uniques = algorithms.factorize(
# -> 2472                 self.grouper, sort=self.sort)
#    2473             uniques = Index(uniques, name=self.name)
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     561         uniques, labels = safe_sort(uniques, labels, na_sentinel=na_sentinel,
# --> 562                                     assume_unique=True)
#     563
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\algorithms.py in safe_sort(values, labels, na_sentinel, assume_unique)
#     518
# --> 519     return ordered, _ensure_platform_int(new_labels)
#     520
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.ensure_platform_int (pandas\_libs\algos.c:57462)()
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.ensure_platform_int (pandas\_libs\algos.c:57333)()
#
# MemoryError:
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in agg_series(self, obj, func)
#    2104         try:
# -> 2105             return self._aggregate_series_fast(obj, func)
#    2106         except Exception:
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in _aggregate_series_fast(self, obj, func)
#    2114
# -> 2115         group_index, _, ngroups = self.group_info
#    2116
#
# pandas\_libs\src\properties.pyx in pandas._libs.lib.cache_readonly.__get__ (pandas\_libs\lib.c:44442)()
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in group_info(self)
#    1799     def group_info(self):
# -> 1800         comp_ids, obs_group_ids = self._get_compressed_labels()
#    1801
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in _get_compressed_labels(self)
#    1806     def _get_compressed_labels(self):
# -> 1807         all_labels = [ping.labels for ping in self.groupings]
#    1808         if len(all_labels) > 1:
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in <listcomp>(.0)
#    1806     def _get_compressed_labels(self):
# -> 1807         all_labels = [ping.labels for ping in self.groupings]
#    1808         if len(all_labels) > 1:
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in labels(self)
#    2459         if self._labels is None:
# -> 2460             self._make_labels()
#    2461         return self._labels
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in _make_labels(self)
#    2471             labels, uniques = algorithms.factorize(
# -> 2472                 self.grouper, sort=self.sort)
#    2473             uniques = Index(uniques, name=self.name)
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     554     check_nulls = not is_integer_dtype(original)
# --> 555     labels = table.get_labels(values, uniques, 0, na_sentinel, check_nulls)
#     556
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_labels (pandas\_libs\hashtable.c:15281)()
#
# MemoryError:
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# <ipython-input-25-bb6ab97db1dc> in <module>()
# ----> 1 newtrain=Train.pivot_table(values="wind",index=["xid","yid","date_id","hour"],columns="model")
#       2 newtrain.head()
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     134
#     135     grouped = data.groupby(keys)
# --> 136     agged = grouped.agg(aggfunc)
#     137
#     138     table = agged
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in aggregate(self, arg, *args, **kwargs)
#    3959         versionadded=''))
#    3960     def aggregate(self, arg, *args, **kwargs):
# -> 3961         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    3962
#    3963     agg = aggregate
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in aggregate(self, arg, *args, **kwargs)
#    3391
#    3392         _level = kwargs.pop('_level', None)
# -> 3393         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    3394         if how is None:
#    3395             return result
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     425         if isinstance(arg, compat.string_types):
#     426             return self._try_aggregate_string_function(arg, *args,
# --> 427                                                        **kwargs), None
#     428
#     429         if isinstance(arg, dict):
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     388         f = getattr(self, arg, None)
#     389         if f is not None:
# --> 390             return f(*args, **kwargs)
#     391
#     392         f = getattr(np, arg, None)
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in mean(self, *args, **kwargs)
#    1041             self._set_group_selection()
#    1042             f = lambda x: x.mean(axis=self.axis, **kwargs)
# -> 1043             return self._python_agg_general(f)
#    1044
#    1045     @Substitution(name='groupby')
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     846         for name, obj in self._iterate_slices():
#     847             try:
# --> 848                 result, counts = self.grouper.agg_series(obj, f)
#     849                 output[name] = self._try_cast(result, obj, numeric_only=True)
#     850             except TypeError:
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in agg_series(self, obj, func)
#    2105             return self._aggregate_series_fast(obj, func)
#    2106         except Exception:
# -> 2107             return self._aggregate_series_pure_python(obj, func)
#    2108
#    2109     def _aggregate_series_fast(self, obj, func):
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in _aggregate_series_pure_python(self, obj, func)
#    2128     def _aggregate_series_pure_python(self, obj, func):
#    2129
# -> 2130         group_index, _, ngroups = self.group_info
#    2131
#    2132         counts = np.zeros(ngroups, dtype=int)
#
# pandas\_libs\src\properties.pyx in pandas._libs.lib.cache_readonly.__get__ (pandas\_libs\lib.c:44442)()
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in group_info(self)
#    1798     @cache_readonly
#    1799     def group_info(self):
# -> 1800         comp_ids, obs_group_ids = self._get_compressed_labels()
#    1801
#    1802         ngroups = len(obs_group_ids)
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in _get_compressed_labels(self)
#    1805
#    1806     def _get_compressed_labels(self):
# -> 1807         all_labels = [ping.labels for ping in self.groupings]
#    1808         if len(all_labels) > 1:
#    1809             group_index = get_group_index(all_labels, self.shape,
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in <listcomp>(.0)
#    1805
#    1806     def _get_compressed_labels(self):
# -> 1807         all_labels = [ping.labels for ping in self.groupings]
#    1808         if len(all_labels) > 1:
#    1809             group_index = get_group_index(all_labels, self.shape,
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in labels(self)
#    2458     def labels(self):
#    2459         if self._labels is None:
# -> 2460             self._make_labels()
#    2461         return self._labels
#    2462
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\groupby.py in _make_labels(self)
#    2470         if self._labels is None or self._group_index is None:
#    2471             labels, uniques = algorithms.factorize(
# -> 2472                 self.grouper, sort=self.sort)
#    2473             uniques = Index(uniques, name=self.name)
#    2474             self._labels = labels
#
# C:\Wesley_Tao\6.Software\Anaconda\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     553     uniques = vec_klass()
#     554     check_nulls = not is_integer_dtype(original)
# --> 555     labels = table.get_labels(values, uniques, 0, na_sentinel, check_nulls)
#     556
#     557     labels = _ensure_platform_int(labels)
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_labels (pandas\_libs\hashtable.c:15281)()
#
# MemoryError:

# %%
newdf=df.pivot_table(values='value', index=['year', 'month'], columns='item')
# Out:
#     month  year  value    item
# 0       1  2004     16  item 1
# 1       2  2004     34  item 1
# 2       3  2004     78  item 1
# 3       4  2004     86  item 1
# 4       5  2004     20  item 1
# 5       6  2004     97  item 1
# 6       7  2004     14  item 1
# 7       8  2004     78  item 1
# 8       9  2004     29  item 1
# 9      10  2004      7  item 1
# 10     11  2004     94  item 1
# 11     12  2004     75  item 1
# 12      1  2004    207  item 2
# 13      2  2004    263  item 2
# 14      3  2004    221  item 2
# 15      4  2004    269  item 2
# 16      5  2004    225  item 2
# 17      6  2004    214  item 2
# 18      7  2004    272  item 2
# 19      8  2004    209  item 2
# 20      9  2004    262  item 2
# 21     10  2004    287  item 2
# 22     11  2004    274  item 2
# 23     12  2004    284  item 2

# %%
newdf=df.pivot_table(values='value', index=['year', 'month'], columns='item')
newdf
# Out:
# item        item 1  item 2
# year month
# 2004 1          16     207
#      2          34     263
#      3          78     221
#      4          86     269
#      5          20     225
#      6          97     214
#      7          14     272
#      8          78     209
#      9          29     262
#      10          7     287
#      11         94     274
#      12         75     284

# %%
print(type(newdf))
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
